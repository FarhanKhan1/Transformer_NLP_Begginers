# %% [markdown]
# <a href="https://colab.research.google.com/github/FarhanKhan1/Transformer_NLP_Begginers/blob/main/language_translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -nc https://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# Out:
# File ‘spa-eng.zip’ already there; not retrieving.

# %%
# !unzip -nq spa-eng.zip

# %%
# !ls
# Out:
# sample_data  spa-eng  spa-eng.zip

# %%
ls spa-eng
# Out:
# _about.txt  spa.txt

# %%
# !head spa-eng/spa.txt
# Out:
# Go.	Ve.
# Go.	Vete.
# Go.	Vaya.
# Go.	Váyase.
# Hi.	Hola.
# Run!	¡Corre!
# Run.	Corred.
# Who?	¿Quién?
# Fire!	¡Fuego!
# Fire!	¡Incendio!

# %%
# eng_to_spa = {}
# list_ = []
# for line in open('spa-eng/spa.txt'):
#   line = line.rstrip()
#   english, spanish = line.split('\t')
#   if english not in eng_to_spa:
#     print("this is", english)
    #print(eng_to_spa)
      #eng_to_spa[english] = []
    #eng_to_spa.english.append(spanish)
# Out:
# Streaming output truncated to the last 5000 lines.
# this is I hope everything is fine at home.
# this is I hope it wasn't too much trouble.
# this is I hope to see my parents tomorrow.
# this is I hope we didn't keep you waiting.
# this is I hope we meet again someday soon.
# this is I hope you know what you're doing.
# this is I hope you'll be comfortable here.
# this is I hope you'll be comfortable here.
# this is I hope you'll be comfortable here.
# this is I hope you'll come again some day.
# this is I hope you've learned your lesson.
# this is I hope your wishes will come true.
# this is I hung my coat in the hall closet.
# this is I intend on fighting till the end.
# this is I intend to stay there for a week.
# this is I introduced her to you last week.
# this is I just bought a new pair of shoes.
# this is I just don't think it's necessary.
# this is I just don't want to let you down.
# this is I just graduated from high school.
# this is I just had a little chat with Tom.
# ...

# %%
list_
# Out:
# []

# %%
# !pip install transformers sentencepiece transformers[sentencepiece]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import pipeline

# %%
translator = pipeline("translation", model='Helsinki-NLP/opus-mt-en-es')
# Out:
# Downloading:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/826k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
translator('Hello, how are you?')
# Out:
# [{'translation_text': 'Hola, ¿cómo estás?'}]
