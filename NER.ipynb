# %% [markdown]
# <a href="https://colab.research.google.com/github/FarhanKhan1/Transformer_NLP_Begginers/blob/main/NER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.3 MB 4.7 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 53.5 MB/s
# ...
#      |████████████████████████████████| 163 kB 70.2 MB/s
# ...

# %%
from transformers import pipeline

# %%
NER = pipeline("ner", aggregation_strategy='simple')
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision f2482bf (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]

# %%
import pickle

# %%
# !wget -nc https://lazyprogrammer.me/course_files/nlp/ner_train.pkl
# !wget -nc https://lazyprogrammer.me/course_files/nlp/ner_test.pkl
# Out:
# --2022-10-31 06:21:16--  https://lazyprogrammer.me/course_files/nlp/ner_train.pkl
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 172.67.213.166, 104.21.23.210, 2606:4700:3031::6815:17d2, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|172.67.213.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4757208 (4.5M) [application/octet-stream]
# Saving to: ‘ner_train.pkl’
#
# ner_train.pkl       100%[===================>]   4.54M  5.49MB/s    in 0.8s
#
# 2022-10-31 06:21:17 (5.49 MB/s) - ‘ner_train.pkl’ saved [4757208/4757208]
#
# --2022-10-31 06:21:17--  https://lazyprogrammer.me/course_files/nlp/ner_test.pkl
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 172.67.213.166, 104.21.23.210, 2606:4700:3031::6815:17d2, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|172.67.213.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1201978 (1.1M) [application/octet-stream]
# Saving to: ‘ner_test.pkl’
#
# ...

# %%
with open('ner_train.pkl', 'rb') as file:
  train_corpus = pickle.load(file)

with open('ner_test.pkl', 'rb') as file:
  test_corpus = pickle.load(file)

# %%
train_corpus
# Out:
# [[('EU', 'B-ORG'),
#   ('rejects', 'O'),
#   ('German', 'B-MISC'),
#   ('call', 'O'),
#   ('to', 'O'),
#   ('boycott', 'O'),
#   ('British', 'B-MISC'),
#   ('lamb', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('European', 'B-ORG'),
#   ('Commission', 'I-ORG'),
#   ('said', 'O'),
#   ('on', 'O'),
#   ('Thursday', 'O'),
#   ('it', 'O'),
#   ('disagreed', 'O'),
#   ('with', 'O'),
#   ('German', 'B-MISC'),
#   ('advice', 'O'),
#   ('to', 'O'),
#   ('consumers', 'O'),
#   ('to', 'O'),
#   ('shun', 'O'),
#   ('British', 'B-MISC'),
#   ('lamb', 'O'),
#   ('until', 'O'),
#   ('scientists', 'O'),
#   ('determine', 'O'),
#   ('whether', 'O'),
#   ('mad', 'O'),
#   ('cow', 'O'),
#   ('disease', 'O'),
#   ('can', 'O'),
#   ('be', 'O'),
#   ('transmitted', 'O'),
#   ('to', 'O'),
#   ('sheep', 'O'),
#   ('.', 'O')],
#  [('Germany', 'B-LOC'),
#   ("'s", 'O'),
#   ('representative', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('European', 'B-ORG'),
#   ('Union', 'I-ORG'),
#   ("'s", 'O'),
# ...

# %%
inputs = []
targets = []

for list_of_tokens in train_corpus:
  
  tokens = []
  target = []
  
  for token, tag in list_of_tokens:
    tokens.append(token)
    target.append(target)
  inputs.append(tokens)
  targets.append(target)

# %%
inputs[3]
# Out:
# ['"',
#  'We',
#  'do',
#  "n't",
#  'support',
#  'any',
#  'such',
#  'recommendation',
#  'because',
#  'we',
#  'do',
#  "n't",
#  'see',
#  'any',
#  'grounds',
#  'for',
#  'it',
#  ',',
#  '"',
#  'the',
#  'Commission',
#  "'s",
#  'chief',
#  'spokesman',
#  'Nikolaus',
#  'van',
#  'der',
#  'Pas',
#  'told',
#  'a',
#  'news',
#  'briefing',
#  '.']

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer
detokenizer = TreebankWordDetokenizer()

# %%
detokenize = detokenizer.detokenize(inputs[3])

# %%
detokenize
# Out:
# '" We don\'t support any such recommendation because we don\'t see any grounds for it, " the Commission\'s chief spokesman Nikolaus van der Pas told a news briefing.'

# %%
NER(detokenizer.detokenize(input[3]))
# Out:
# [{'entity_group': 'ORG',
#   'score': 0.9984792,
#   'word': 'Commission',
#   'start': 90,
#   'end': 100},
#  {'entity_group': 'PER',
#   'score': 0.9948291,
#   'word': 'Nikolaus van der Pas',
#   'start': 119,
#   'end': 139}]
